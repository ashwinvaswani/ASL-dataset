# %%
import os

# %%
current_dir = os.path.dirname(os.path.abspath('__file__'))
current_dir = current_dir + '/asl_alphabet_train/'
print(current_dir)
# Out:
# /media/ubnutu/Windows/Users/hp/Documents/GitHub/ASL-dataset/asl_alphabet_train/

# %%
for folder in sorted(os.listdir(current_dir)):
    #print(folder)
    new_dir = current_dir + folder + '/'
    print(new_dir)
    cnt = 1
    for filename in sorted(os.listdir(new_dir)):
        #print(filename[1:5]) 
        if cnt <= 2000:
            os.remove(new_dir + filename)
            print(filename + "removed")           
            cnt += 1
# Out:
# /media/ubnutu/Windows/Users/hp/Documents/GitHub/ASL-dataset/asl_alphabet_train/A/
# A2001.jpgremoved
# A2002.jpgremoved
# A2003.jpgremoved
# A2004.jpgremoved
# A2005.jpgremoved
# A2006.jpgremoved
# A2007.jpgremoved
# A2008.jpgremoved
# A2009.jpgremoved
# A2010.jpgremoved
# A2011.jpgremoved
# A2012.jpgremoved
# A2013.jpgremoved
# A2014.jpgremoved
# A2015.jpgremoved
# A2016.jpgremoved
# A2017.jpgremoved
# A2018.jpgremoved
# A2019.jpgremoved
# A2020.jpgremoved
# A2021.jpgremoved
# A2022.jpgremoved
# A2023.jpgremoved
# A2024.jpgremoved
# A2025.jpgremoved
# A2026.jpgremoved
# A2027.jpgremoved
# A2028.jpgremoved
# A2029.jpgremoved
# A2030.jpgremoved
# A2031.jpgremoved
# A2032.jpgremoved
# A2033.jpgremoved
# A2034.jpgremoved
# A2035.jpgremoved
# A2036.jpgremoved
# A2037.jpgremoved
# A2038.jpgremoved
# A2039.jpgremoved
# A2040.jpgremoved
# A2041.jpgremoved
# A2042.jpgremoved
# A2043.jpgremoved
# A2044.jpgremoved
# A2045.jpgremoved
# A2046.jpgremoved
# A2047.jpgremoved
# A2048.jpgremoved
# ...
